# %%
import pandas as pd
import numpy as np
from DB import Spotify
import backendFunc
import os
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
# Out:
# /tmp/ipykernel_2694/3062688168.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# # 0.抓資料

# %%
# request information through API
search_ID = os.getenv("SPOTIFY_TOKEN_OWNER")
search_ID
# Out:
# ''

# %%
type, token = backendFunc.checkToken('spotify_token', search_ID)
print(type)
print(token)
# Out:
# Bearer
# BQBGLQS6LuoGkiUAotzdA5Fu3CUC6lPFQQJ8ufdgpeHW6mbyiGxkEXjweHU54_7P-jPMPtX5dV42OydERw_t_vNEuIjmShkXj38Oc2wfxAClga9kfzA

# %%
headers = {'Authorization': f"{type} {token}"}
headers
# Out:
# {'Authorization': 'Bearer BQBGLQS6LuoGkiUAotzdA5Fu3CUC6lPFQQJ8ufdgpeHW6mbyiGxkEXjweHU54_7P-jPMPtX5dV42OydERw_t_vNEuIjmShkXj38Oc2wfxAClga9kfzA'}

# %%
# eg.
_rapID = Spotify('rap_ID')
cursor = _rapID.collection.find({'id':'Kanye West'})
for c in cursor:
    print(c)
# Out:
# {'_id': ObjectId('656edfa71de3a5a97258fc58'), 'id': 'Kanye West', 'artist_ID_url': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x', 'playlist_ID_url': 'https://open.spotify.com/album/2Ek1q2haOnxVqhvVKqMvJe'}

# %%
# get_artist ENDPOINT https://api.spotify.com/v1/artists/{id}
artist_endpoint = r'https://api.spotify.com/v1/artists/'
ye_id = r'5K4W6rqBFWDnAN6FQUkS6x'
response = backendFunc.requestUrl(artist_endpoint+ye_id, headers, 'json')
print(response)
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'}, 'followers': {'href': None, 'total': 24822963}, 'genres': ['chicago rap', 'hip hop', 'rap'], 'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x', 'id': '5K4W6rqBFWDnAN6FQUkS6x', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb6e835a500e791bf9c27a422a', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab676161000051746e835a500e791bf9c27a422a', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f1786e835a500e791bf9c27a422a', 'width': 160}], 'name': 'Kanye West', 'popularity': 94, 'type': 'artist', 'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'}

# %%
# 想要的形式為
origin_data = c.copy()
origin_data
# Out:
# {'_id': ObjectId('656edfa71de3a5a97258fc58'),
#  'id': 'Kanye West',
#  'artist_ID_url': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x',
#  'playlist_ID_url': 'https://open.spotify.com/album/2Ek1q2haOnxVqhvVKqMvJe'}

# %%
type(dict(origin_data))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 type(dict(origin_data))
#
# TypeError: 'str' object is not callable

# %%
response
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#  'followers': {'href': None, 'total': 24762907},
#  'genres': ['chicago rap', 'hip hop', 'rap'],
#  'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#  'id': '5K4W6rqBFWDnAN6FQUkS6x',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab6761610000e5eb6e835a500e791bf9c27a422a',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/ab676161000051746e835a500e791bf9c27a422a',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/ab6761610000f1786e835a500e791bf9c27a422a',
#    'width': 160}],
#  'name': 'Kanye West',
#  'popularity': 94,
#  'type': 'artist',
#  'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'}

# %%
artist_endpoint
# Out:
# 'https://api.spotify.com/v1/artists/'

# %%
final_data = origin_data.copy()
# 將id 轉換為name
final_data['name'] = final_data.pop('id')
# id 給 spotify_id
final_data['spotify_id'] = final_data['artist_ID_url'].replace(r'https://open.spotify.com/artist/', "")
final_data['followers'] = response['followers']['total']
final_data['popularity'] = response['popularity']
final_data['genres'] = response['genres']
final_data
# Out:
# {'_id': ObjectId('656edfa71de3a5a97258fc58'),
#  'artist_ID_url': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x',
#  'playlist_ID_url': 'https://open.spotify.com/album/2Ek1q2haOnxVqhvVKqMvJe',
#  'name': 'Kanye West',
#  'spotify_id': '5K4W6rqBFWDnAN6FQUkS6x',
#  'followers': 24762907,
#  'popularity': 94,
#  'genres': ['chicago rap', 'hip hop', 'rap']}

# %% [markdown]
# # 1. 整理rap_ID

# %% [markdown]
# ## 1-1. 清理 rap_ID collection/刪除重複

# %%
_rapID = Spotify('rap_ID')
_rapID.collection.count_documents({})
# Out:
# 1417

# %%
# 查重複資料
# 获取重复的文档
pipeline = [
    {"$group": {"_id": "$id", "count": {"$sum": 1}}},
    {"$match": {"count": {"$gt": 1}}}
]
duplicate_documents = list(_rapID.collection.aggregate(pipeline))

duplicate_documents
# Out:
# [{'_id': 'Lil Mama', 'count': 2},
#  {'_id': 'Guilty Simpson', 'count': 2},
#  {'_id': 'Gilbere Forte', 'count': 2},
#  {'_id': 'Half a Mill', 'count': 2},
#  {'_id': 'Gudda Gudda', 'count': 2},
#  {'_id': 'Gnar', 'count': 2},
#  {'_id': 'Hard Kaur', 'count': 2},
#  {'_id': 'Grand Puba', 'count': 2},
#  {'_id': 'Grieves', 'count': 2},
#  {'_id': 'Boogie', 'count': 2},
#  {'_id': 'Grafh', 'count': 2},
#  {'_id': 'Gunna', 'count': 2},
#  {'_id': 'Mister Cee', 'count': 2},
#  {'_id': 'Ghostemane', 'count': 2},
#  {'_id': 'Gucci Mane', 'count': 2},
#  {'_id': 'Guerilla Black', 'count': 2},
#  {'_id': 'Giggs', 'count': 2},
#  {'_id': 'Gunplay', 'count': 2},
#  {'_id': 'Gorilla Zoe', 'count': 2},
#  {'_id': 'Mopreme Shakur', 'count': 2},
#  {'_id': 'Grandmaster Caz', 'count': 2},
#  {'_id': 'GZA', 'count': 2},
#  {'_id': 'Mos Def', 'count': 2},
#  {'_id': 'Greydon Square', 'count': 2},
#  {'_id': 'Hanhae', 'count': 2},
#  {'_id': 'GLC', 'count': 2},
#  {'_id': 'Goldie Loc', 'count': 2},
# ...

# %%
# 删除重复的文档，保留第一次出现的文档
for document in duplicate_documents:
    document_id = document['_id']
    first_document = _rapID.collection.find_one({"id": document_id})
    _rapID.collection.delete_many({"id": document_id, "_id": {"$ne": first_document["_id"]}})

# %%
# check
cursor = _rapID.collection.find({'id':'[1]'})
for c in cursor:
    print(c)
# Out:
# {'_id': ObjectId('656ebcba2452069bed743266'), 'id': '[1]', 'artist_ID_url': 'https://open.spotify.com/artist/36Hd8M3GV2FLpHUEDH6bCz', 'playlist_ID_url': 'https://en.wikipedia.org/wiki/List_of_most-streamed_artists_on_Spotify'}

# %%
# check 2
duplicate_documents2 = list(_rapID.collection.aggregate(pipeline))

duplicate_documents2
# Out:
# []

# %%
_rapID.collection.count_documents({})
# Out:
# 1363

# %% [markdown]
# ## 每個rap_ID的都是unique

# %% [markdown]
# ## 觀察 artist url 確認符合形式

# %%
# 'artist_ID_url': 'https://open.spotify.com/artist/',
# 如果否 刪除document

# %%
# show rap_ID artist_ID_url not correct
artist_ID_url = 'https://open.spotify.com/artist/'
# 搜尋不包含特定字串的文件
cursors = _rapID.collection.find(
    {"artist_ID_url": {"$not": {"$regex": artist_ID_url}}}
    )

# 輸出結果
for doc in cursors:
    print(doc['id'])
    print(doc['artist_ID_url'])
# Out:
# Arthur Dubois
# https://open.spotify.com/user/1166193561
# Bob Doe
# https://open.spotify.com/album/3JEkOQ0OoeDN7jDA6qEkT8
# Dee Barnes
# https://open.spotify.com/user/dianneripoll
# Disco King Mario
# https://open.spotify.com/album/3Gm8D0QeqcidAevL9LwUQi
# Duncan Mighty
# https://open.spotify.com/playlist/37i9dQZF1EIZ6gztYya4jy
# MC Mong
# https://open.spotify.com/album/6iIpf4O5d6BXdl7ahJzO2e
# MF Grimm
# https://open.spotify.com/playlist/37i9dQZF1E4B3McCPjjmJH
# The Quiett
# https://open.spotify.com/track/0C4GnG56O7HPCwwfCyqLOl
# The Real Roxanne
# https://open.spotify.com/intl-fr/album/1GaU037lWFDr9qu19zDuIk
# Silentó
# https://kworb.net/spotify/artist/7juKTDFlPesGeWQ1GmjmOv.html

# %%
count = _rapID.collection.count_documents(
    {"artist_ID_url": {"$not": {"$regex": "https://open.spotify.com/artist/"}}}
    )
count
# Out:
# 16

# %%
count = _rapID.collection.count_documents(
    {"artist_ID_url": {"$not": {"$regex": "https://open.spotify.com/artist/"}}}
    )
count
# Out:
# 10

# %%
import os
import requests
from googlesearch import search
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import random
import time

# %%
cursord = _rapID.collection.find(
    {"id": "Duncan Mighty"}
    )
for i, cu in enumerate(cursord):
    #cu['test'] = 'test'
    print(cu)
# Out:
# {'_id': ObjectId('656ecac1ff2e82f6be653126'), 'id': 'Duncan Mighty', 'artist_ID_url': 'https://open.spotify.com/playlist/37i9dQZF1EIZ6gztYya4jy', 'playlist_ID_url': 'https://open.spotify.com/playlist/37i9dQZF1EIZ6gztYya4jy'}

# %%
# 有16筆數據 artist_ID_url 不符形式
# 更新
cursors = _rapID.collection.find(
    {"artist_ID_url": {"$not": {"$regex": artist_ID_url}}}
    )

filter1 = 'https://open.spotify.com/artist'
filter2 = 'https://open.spotify.com/playlist'

# 輸出結果
for i, doc in enumerate(cursors):
    print(doc['id'])
    name = doc['id']
    # google search 比對字串
    result = search(f'{name} spotify', 
                    sleep_interval= random.randint(3,13), 
                    num_results=3)
    
    for idx, value in enumerate(result):
        
        if filter1 in value:
            print(i, 'change', name, 'artist_ID_url')
            # 更新artist_url
            _rapID.update_one('id', name,'artist_ID_url', value)
        elif filter2 in value:            
            print(i, 'change', name, 'playlist_ID_url')
            _rapID.update_one('id', name,'playlist_ID_url', value)
        else:
            continue
# 有些搜尋不到 / 手工做
# Out:
# André 3000
# 0 change André 3000 artist_ID_url
# 0 change André 3000 playlist_ID_url
# 0 change André 3000 playlist_ID_url
# Arthur Dubois
# Bob Doe
# 2 change Bob Doe playlist_ID_url
# Dee Barnes
# 3 change Dee Barnes playlist_ID_url
# Disco King Mario
# Duncan Mighty
# Jake One
# 6 change Jake One artist_ID_url
# 6 change Jake One playlist_ID_url
# 6 change Jake One playlist_ID_url
# Jeremiah Jae
# 7 change Jeremiah Jae artist_ID_url
# 7 change Jeremiah Jae playlist_ID_url
# Kidd Kidd
# 8 change Kidd Kidd artist_ID_url
# Mack Maine
# 9 change Mack Maine artist_ID_url
# 9 change Mack Maine playlist_ID_url
# 9 change Mack Maine artist_ID_url
# MC Mong
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 19
#      14 # google search 比對字串
#      15 result = search(f'{name} spotify',
#      16                 sleep_interval= random.randint(3,13),
# ...

# %%
# 手工找 手工解決
# show rap_ID artist_ID_url not correct
artist_ID_url = 'https://open.spotify.com/artist/'
# 搜尋不包含特定字串的文件
cursors = _rapID.collection.find(
    {"artist_ID_url": {"$not": {"$regex": artist_ID_url}}}
    )

# 輸出結果
for doc in cursors:
    print(doc['id'])
    print(doc['artist_ID_url'])

# %%
from pymongo import MongoClient

# 連接到 MongoDB 資料庫
client = MongoClient('mongodb://localhost:27017/')
db = client['your_database']  # 替換成你的資料庫名稱
collection = db['your_collection']  # 替換成你的集合名稱

# 定義要更新的條件和更新的內容
filter = {"name": "John"}
update = {"$set": {"age": 30}}

# 更新集合中符合條件的第一個文檔
result = collection.update_one(filter, update)

print("匹配的文檔數量:", result.matched_count)
print("修改的文檔數量:", result.modified_count)

# %%
result = search(f'Mack Maine spotify', 
                sleep_interval= random.randint(3,13), 
                num_results=2)
for idx2, element in enumerate(result):
    print(idx2, element)
# Out:
# 0 https://open.spotify.com/playlist/37i9dQZF1DZ06evO0C08oG
# 1 https://open.spotify.com/artist/1ugWqV4zgRf4JrVbrZg7Io
# 2 https://open.spotify.com/track/5eWzesrjifebihwx0VUFTQ

# %%
filter1 = 'https://open.spotify.com/artist'
element.find(filter1)
# Out:
# -1

# %% [markdown]
# ## 1-2. each rap_ID add popularity / followers / genres

# %%
h = _rapID.collection.find()
for hh in h:
    print(hh['j'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[52], line 3
#       1 h = _rapID.collection.find()
#       2 for hh in h:
# ----> 3     print(hh['j'])
#
# KeyError: 'j'

# %%
docs = old_rapID.collection.find().limit(1)
print(doc)
# Out:
# {'_id': ObjectId('656eb822f97cf2612d537caa'), 'artist_ID_url': 'https://open.spotify.com/track/3a2viq7Z8uQmHsogn1G6B6', 'playlist_ID_url': 'https://open.spotify.com/playlist/37i9dQZF1E4zlh0lHbELbi', 'name': '$2 Fabo', 'spotify_id': 'https://open.spotify.com/track/3a2viq7Z8uQmHsogn1G6B6'}

# %%
old_rapID = Spotify('rap_ID')
new_rapID = Spotify('new_rap_ID')
docs = old_rapID.collection.find()
artist_endpoint = r'https://api.spotify.com/v1/artists/'

for doc in docs:
    # old rap_ID documnet
    # add name / remove old id
    doc['name'] = doc.pop('id')
    # get unique spotify_id
    spotify_id = doc['artist_ID_url'].replace(r'https://open.spotify.com/artist/', "")
    doc['spotify_id'] = spotify_id

    # using spotify api get artist
    response = backendFunc.requestUrl(artist_endpoint+spotify_id, headers, 'json')
    doc['followers'] = response['followers']['total']
    doc['popularity'] = response['popularity']
    doc['genres'] = response['genres']
    doc.pop('_id', None) 
    new_rapID.insert_one(doc)



# final_data = origin_data.copy()
# # 將id 轉換為name
# final_data['name'] = final_data.pop('id')
# # id 給 spotify_id
# final_data['spotify_id'] = final_data['artist_ID_url'].replace(r'https://open.spotify.com/artist/', "")
# final_data['followers'] = response['followers']['total']
# final_data['popularity'] = response['popularity']
# final_data['genres'] = response['genres']
# final_data

# # get_artist ENDPOINT https://api.spotify.com/v1/artists/{id}
# ye_id = r'5K4W6rqBFWDnAN6FQUkS6x'
# response = backendFunc.requestUrl(artist_endpoint+ye_id, headers, 'json')
# print(response)

# %% [markdown]
# ## 1-3. each rap_ID add album / single

# %%
album_album_url = [f'https://api.spotify.com/v1/artists/', 
                   f'/albums?include_groups=album&limit=50']
album_single_url = [f'https://api.spotify.com/v1/artists/', 
                    f'/albums?include_groups=single&limit=50']

# %%
# eg.
newrapID = Spotify('new_rap_ID')
cursor = newrapID.collection.find({'name':'Kanye West'})
for c in cursor:
    print(c)
# Out:
# {'_id': ObjectId('6618d99c1c4723b68ac22f24'), 'artist_ID_url': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x', 'playlist_ID_url': 'https://open.spotify.com/album/2Ek1q2haOnxVqhvVKqMvJe', 'name': 'Kanye West', 'spotify_id': '5K4W6rqBFWDnAN6FQUkS6x', 'followers': 24777743, 'popularity': 94, 'genres': ['chicago rap', 'hip hop', 'rap'], 'total_albums': 16, 'albums': [{'album_name': 'VULTURES 1', 'total_tracks_num': 16, 'album_id': '30zwjSQEodaUXCn11nmiVF', 'release_date': '2024-02-09', 'total_artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4xPQFgDA5M2xa0ZGo5iIsv'}, 'href': 'https://api.spotify.com/v1/artists/4xPQFgDA5M2xa0ZGo5iIsv', 'id': '4xPQFgDA5M2xa0ZGo5iIsv', 'name': '¥$', 'type': 'artist', 'uri': 'spotify:artist:4xPQFgDA5M2xa0ZGo5iIsv'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'}, 'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x', 'id': '5K4W6rqBFWDnAN6FQUkS6x', 'name': 'Kanye West', 
# ...

# %%
album_album_url[0]
# Out:
# 'https://api.spotify.com/v1/artists/'

# %%
spotify_id = '5K4W6rqBFWDnAN6FQUkS6x'
album_url=  album_album_url[0]+spotify_id+album_album_url[1]
#album_url = 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x/albums?include_groups=album&limit=10'

single_url=  album_single_url[0]+spotify_id+album_single_url[1]

response = backendFunc.requestUrl(album_url, headers, 'json')

print(response)

response1 = backendFunc.requestUrl(single_url, headers, 'json')
print(response1)
# Out:
# {'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x/albums?include_groups=album&offset=0&limit=50', 'items': [{'album_group': 'album', 'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4xPQFgDA5M2xa0ZGo5iIsv'}, 'href': 'https://api.spotify.com/v1/artists/4xPQFgDA5M2xa0ZGo5iIsv', 'id': '4xPQFgDA5M2xa0ZGo5iIsv', 'name': '¥$', 'type': 'artist', 'uri': 'spotify:artist:4xPQFgDA5M2xa0ZGo5iIsv'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'}, 'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x', 'id': '5K4W6rqBFWDnAN6FQUkS6x', 'name': 'Kanye West', 'type': 'artist', 'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/7c0XG5cIJTrrAgEC3ULPiq'}, 'href': 'https://api.spotify.com/v1/artists/7c0XG5cIJTrrAgEC3ULPiq', 'id': '7c0XG5cIJTrrAgEC3ULPiq', 'name': 'Ty Dolla $ign', 'type': 'artist', 'uri': 'spotify:artist:7c0XG5
# ...

# %%
for i in range(len(response['items'])):
    print(response['items'][i]['name'])
for i in range(len(response1['items'])):
    print(response1['items'][i]['name'])

print(len(response['items']))
print(len(response1['items']))
# Out:
# VULTURES 1
# Donda (Deluxe)
# Donda
# JESUS IS KING
# KIDS SEE GHOSTS
# ye
# The Life Of Pablo
# Yeezus
# Watch The Throne (Deluxe)
# Watch The Throne
# My Beautiful Dark Twisted Fantasy
# 808s & Heartbreak
# Graduation
# Late Orchestration
# Late Registration
# The College Dropout
# CARNIVAL PACK (feat. Rich The Kid, Playboi Carti)
# CARNIVAL - HOOLIGANS VERSION
# CARNIVAL (feat. Rich The Kid, Playboi Carti)
# CARNIVAL (INSTRUMENTAL)
# TALKING
# VULTURES PACK
# VULTURES
# VULTURES
# Where They At
# Stand United
# Hot Shit (feat. Ye & Lil Durk)
# Hot Shit (feat. Ye & Lil Durk) [Instrumental]
# Eazy
# True Love
# City of Gods
# Hurricane
# Life Of The Party
# Wash Us In The Blood
# I Love It
# XTCY
# Lift Yourself
# Ye vs. the People (starring TI as the People)
# All Day
# FourFiveSeconds
# Only One
# New God Flow
# Mercy
# Cold
# Runaway (Explicit Version)
# Christmas In Harlem
# Paranoid
# Stronger
# Good Life
# Touch The Sky
# Diamonds from Sierra Leone Remix ft Jay.z
# ...

# %%
response
# Out:
# {'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x/albums?include_groups=album&offset=0&limit=50',
#  'items': [{'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4xPQFgDA5M2xa0ZGo5iIsv'},
#      'href': 'https://api.spotify.com/v1/artists/4xPQFgDA5M2xa0ZGo5iIsv',
#      'id': '4xPQFgDA5M2xa0ZGo5iIsv',
#      'name': '¥$',
#      'type': 'artist',
#      'uri': 'spotify:artist:4xPQFgDA5M2xa0ZGo5iIsv'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#      'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#      'id': '5K4W6rqBFWDnAN6FQUkS6x',
#      'name': 'Kanye West',
#      'type': 'artist',
#      'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/7c0XG5cIJTrrAgEC3ULPiq'},
#      'href': 'https://api.spotify.com/v1/artists/7c0XG5cIJTrrAgEC3ULPiq',
# ...

# %%
response['items'][3]
# Out:
# {'album_group': 'album',
#  'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#    'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#    'id': '5K4W6rqBFWDnAN6FQUkS6x',
#    'name': 'Kanye West',
#    'type': 'artist',
#    'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'}],
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
# ...

# %%
response['href']
# Out:
# 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x/albums?include_groups=album&offset=0&limit=50'

# %%
# albums下面的東西

# album_name(unique)
# album_id(unique)
# artist_name(multi)
# total_tracks(unique)
# release date(unique)

# album_type(unique)
# images(multi)

# %%
# origin
c2 = c.copy()
c2
# Out:
# {'_id': ObjectId('6618d99c1c4723b68ac22f24'),
#  'artist_ID_url': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x',
#  'playlist_ID_url': 'https://open.spotify.com/album/2Ek1q2haOnxVqhvVKqMvJe',
#  'name': 'Kanye West',
#  'spotify_id': '5K4W6rqBFWDnAN6FQUkS6x',
#  'followers': 24777743,
#  'popularity': 94,
#  'genres': ['chicago rap', 'hip hop', 'rap'],
#  'total_albums': 16,
#  'albums': [{'album_name': 'VULTURES 1',
#    'total_tracks_num': 16,
#    'album_id': '30zwjSQEodaUXCn11nmiVF',
#    'release_date': '2024-02-09',
#    'total_artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4xPQFgDA5M2xa0ZGo5iIsv'},
#      'href': 'https://api.spotify.com/v1/artists/4xPQFgDA5M2xa0ZGo5iIsv',
#      'id': '4xPQFgDA5M2xa0ZGo5iIsv',
#      'name': '¥$',
#      'type': 'artist',
#      'uri': 'spotify:artist:4xPQFgDA5M2xa0ZGo5iIsv'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
# ...

# %%
response['items'][4]
# Out:
# {'album_group': 'album',
#  'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2hPgGN4uhvXAxiXQBIXOmE'},
#    'href': 'https://api.spotify.com/v1/artists/2hPgGN4uhvXAxiXQBIXOmE',
#    'id': '2hPgGN4uhvXAxiXQBIXOmE',
#    'name': 'KIDS SEE GHOSTS',
#    'type': 'artist',
#    'uri': 'spotify:artist:2hPgGN4uhvXAxiXQBIXOmE'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#    'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#    'id': '5K4W6rqBFWDnAN6FQUkS6x',
#    'name': 'Kanye West',
#    'type': 'artist',
#    'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/0fA0VVWsXO9YnASrzqfmYu'},
#    'href': 'https://api.spotify.com/v1/artists/0fA0VVWsXO9YnASrzqfmYu',
#    'id': '0fA0VVWsXO9YnASrzqfmYu',
#    'name': 'Kid Cudi',
#    'type': 'artist',
#    'uri': 'spotify:artist:0fA0VVWsXO9YnASrzqfmYu'}],
# ...

# %%
if response['next'] is None:
    #
    c2['total_albums'] = response['total']
    c2['albums'] = []
    for i in range(len(response['items'])):
        one_album = response['items'][i]
        temp_dict = {}
        temp_dict['album_name'] = one_album['name']
        temp_dict['total_tracks_num'] = one_album['total_tracks']
        temp_dict['album_id'] = one_album['id']
        temp_dict['release_date'] = one_album['release_date']
        temp_dict['total_artists'] = one_album['artists']
        temp_dict['album_type'] = one_album['album_type']
        temp_dict['images'] = one_album['images']

        c2['albums'].append(temp_dict)
c2
# else:
#     while response['next'] not None:
#         response = backendFunc.requestUrl(response['next'], headers, 'json')
# Out:
# {'_id': ObjectId('6618d99c1c4723b68ac22f24'),
#  'artist_ID_url': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x',
#  'playlist_ID_url': 'https://open.spotify.com/album/2Ek1q2haOnxVqhvVKqMvJe',
#  'name': 'Kanye West',
#  'spotify_id': '5K4W6rqBFWDnAN6FQUkS6x',
#  'followers': 24777743,
#  'popularity': 94,
#  'genres': ['chicago rap', 'hip hop', 'rap'],
#  'total_albums': 16,
#  'albums': [{'album_name': 'VULTURES 1',
#    'total_tracks_num': 16,
#    'album_id': '30zwjSQEodaUXCn11nmiVF',
#    'release_date': '2024-02-09',
#    'total_artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4xPQFgDA5M2xa0ZGo5iIsv'},
#      'href': 'https://api.spotify.com/v1/artists/4xPQFgDA5M2xa0ZGo5iIsv',
#      'id': '4xPQFgDA5M2xa0ZGo5iIsv',
#      'name': '¥$',
#      'type': 'artist',
#      'uri': 'spotify:artist:4xPQFgDA5M2xa0ZGo5iIsv'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
# ...

# %%
c2['albums']
# Out:
# [{'album_name': 'VULTURES 1',
#   'total_tracks_num': 16,
#   'album_id': '30zwjSQEodaUXCn11nmiVF',
#   'release_date': '2024-02-09',
#   'total_artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4xPQFgDA5M2xa0ZGo5iIsv'},
#     'href': 'https://api.spotify.com/v1/artists/4xPQFgDA5M2xa0ZGo5iIsv',
#     'id': '4xPQFgDA5M2xa0ZGo5iIsv',
#     'name': '¥$',
#     'type': 'artist',
#     'uri': 'spotify:artist:4xPQFgDA5M2xa0ZGo5iIsv'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#     'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#     'id': '5K4W6rqBFWDnAN6FQUkS6x',
#     'name': 'Kanye West',
#     'type': 'artist',
#     'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7c0XG5cIJTrrAgEC3ULPiq'},
#     'href': 'https://api.spotify.com/v1/artists/7c0XG5cIJTrrAgEC3ULPiq',
#     'id': '7c0XG5cIJTrrAgEC3ULPiq',
# ...

# %%
# 確定有href 來更新 增加 doc的 albums欄位
def add_album_from_response(old_dict, response):
    # init response
    
    # try:
    #     response = backendFunc.requestUrl(artist_album_url, headers, 'json')
    # except:
    #     print('soptify api error')
    #     # update headers
    #     type, token = backendFunc.checkToken('spotify_token', search_ID)
    #     headers = {'Authorization': f"{type} {token}"}
    #     response = backendFunc.requestUrl(artist_album_url, headers, 'json')

    new_dict = old_dict.copy()

    if 'albums' not in new_dict.keys():
        new_dict['total_albums'] = response['total']
        new_dict['albums'] = []
    # else:
    #     new_dict['total_albums'] = new_dict['total_albums']+ response['total']

    for i in range(len(response['items'])): # for each album in item
        one_album = response['items'][i]
        temp_dict = {}
        temp_dict['album_name'] = one_album['name']
        temp_dict['total_tracks_num'] = one_album['total_tracks']
        temp_dict['album_id'] = one_album['id']
        temp_dict['release_date'] = one_album['release_date']
        temp_dict['total_artists'] = one_album['artists']
        temp_dict['album_type'] = one_album['album_type']
        temp_dict['images'] = one_album['images']

        new_dict['albums'].append(temp_dict)     

    return new_dict

# %%
cursor = newrapID.collection.find({'name':'Nas'})
for c in cursor:
    print(c)
nas_album_url = album_album_url[0]+c['spotify_id']+album_album_url[1]
nas_album_url
# Out:
# {'_id': ObjectId('6618da3e1c4723b68ac2322a'), 'artist_ID_url': 'https://open.spotify.com/artist/20qISvAhX20dpIbOOzGK3q', 'playlist_ID_url': 'https://kworb.net/spotify/artist/20qISvAhX20dpIbOOzGK3q_songs.html', 'name': 'Nas', 'spotify_id': '20qISvAhX20dpIbOOzGK3q', 'followers': 3655404, 'popularity': 72, 'genres': ['conscious hip hop', 'east coast hip hop', 'gangster rap', 'hardcore hip hop', 'hip hop', 'queens hip hop', 'rap'], 'total_albums': 25, 'albums': [{'album_name': 'Magic 3', 'total_tracks_num': 15, 'album_id': '1NLLTGSKTYOvlFKFtRXFGz', 'release_date': '2023-09-14', 'total_artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/20qISvAhX20dpIbOOzGK3q'}, 'href': 'https://api.spotify.com/v1/artists/20qISvAhX20dpIbOOzGK3q', 'id': '20qISvAhX20dpIbOOzGK3q', 'name': 'Nas', 'type': 'artist', 'uri': 'spotify:artist:20qISvAhX20dpIbOOzGK3q'}], 'album_type': 'album', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b2733351a95566bd90522817943e', '
# ...

# %%
if '_id' in c.keys():
    print(True)
# Out:
# True

# %%
response = backendFunc.requestUrl(nas_album_url, headers, 'json')
#nas_new_dict = add_album_from_response(c, response)
nas_new_dict
# Out:
# {'_id': ObjectId('6618da3e1c4723b68ac2322a'),
#  'artist_ID_url': 'https://open.spotify.com/artist/20qISvAhX20dpIbOOzGK3q',
#  'playlist_ID_url': 'https://kworb.net/spotify/artist/20qISvAhX20dpIbOOzGK3q_songs.html',
#  'name': 'Nas',
#  'spotify_id': '20qISvAhX20dpIbOOzGK3q',
#  'followers': 3655404,
#  'popularity': 72,
#  'genres': ['conscious hip hop',
#   'east coast hip hop',
#   'gangster rap',
#   'hardcore hip hop',
#   'hip hop',
#   'queens hip hop',
#   'rap'],
#  'total_albums': 25,
#  'albums': [{'album_name': 'Magic 3',
#    'total_tracks_num': 15,
#    'album_id': '1NLLTGSKTYOvlFKFtRXFGz',
#    'release_date': '2023-09-14',
#    'total_artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/20qISvAhX20dpIbOOzGK3q'},
#      'href': 'https://api.spotify.com/v1/artists/20qISvAhX20dpIbOOzGK3q',
#      'id': '20qISvAhX20dpIbOOzGK3q',
#      'name': 'Nas',
#      'type': 'artist',
#      'uri': 'spotify:artist:20qISvAhX20dpIbOOzGK3q'}],
# ...

# %%
# 要更新的条件
query = {'name': 'John'}
# 新的文档数据
new_document = {
    'name': 'John',
    'age': 30,
    'city': 'New York'
}
# 使用 replace_one() 方法替换匹配条件的第一个文档
collection.replace_one(query, new_document)
# 关闭 MongoDB 连接
client.close()

# %%
# 更新 new_rap_ID
newrapID = Spotify('new_rap_ID')
type, token = backendFunc.checkToken('spotify_token', search_ID)
headers = {'Authorization': f"{type} {token}"}
docs = newrapID.collection.find({})

error_list = []
for index,doc in enumerate(docs):
    if '_id' in doc.keys():
        del doc['_id']
    # each doc get artist_album_url
    artist_album_url = album_album_url[0]+doc['spotify_id']+album_album_url[1]
    
    try:
        # 抓資料
        try:
            init_response = backendFunc.requestUrl(artist_album_url, headers, 'json')
        except:
            print('soptify api error and update headers')
            # update headers
            type, token = backendFunc.checkToken('spotify_token', search_ID)
            headers = {'Authorization': f"{type} {token}"}
            init_response = backendFunc.requestUrl(artist_album_url, headers, 'json')


        response  = init_response
        artist_new_dict = add_album_from_response(doc, response)
        while response['next'] is not None:
            # 抓資料
            try:
                after_response = backendFunc.requestUrl(response['next'], headers, 'json')
            except:
                print('soptify api error')
                # update headers
                type, token = backendFunc.checkToken('spotify_token', search_ID)
                headers = {'Authorization': f"{type} {token}"}
                after_response = backendFunc.requestUrl(response['next'], headers, 'json')
            
            artist_new_dict = add_album_from_response(artist_new_dict, after_response)
            response = after_response
        # 更新資料
        # 使用 replace_one() 方法替换匹配条件的第一个文档
        query = {'spotify_id': doc['spotify_id']}
        newrapID.collection.replace_one(query, artist_new_dict)
        #print("update index ", index, 'done')

    except:
        temp_err_dict = {}
        temp_err_dict['index'] = index
        temp_err_dict['artist_name'] = doc['name']
        temp_err_dict['spotify_id'] = doc['spotify_id']

        print("index ", index, ' error')
        print("append index and artist name")
        error_list.append(temp_err_dict)
# Out:
# index  262  error
# append index and artist name

# %%
# 查看 error
error_list[0]
# Out:
# {'index': 262,
#  'artist_name': 'Cordaro Stewart',
#  'spotify_id': '3GhvpQmv0mmLJpQsi7KNKw?aid=&cid=&ctid=&ep_mid=5894031&ep_rid=200243583&mid=&offer=Check+%27Em+Out+Button&play=true&redirect=%2Fprograms%2Fkids-and-family-collection%2Fworkouts&utm_medium=open&utm_source=open.spotify.com'}

# %%
# 尋找collection裡沒有albums 這個field的doc
ccc = newrapID.collection.aggregate([{
        "$match": {
            "albums": { "$exists": False }
        }
    }])
for cc1 in ccc:
    print(cc1['name'])
# Out:
# Boogie
# Cordaro Stewart
# Lil’ Flip
# Torch (German)
# Yo-Yo

# %%
# 看response
# 尋找collection裡沒有albums 這個field的doc
ccc = newrapID.collection.aggregate([{
        "$match": {
            "albums": { "$exists": False }
        }
    }])

err_res_list = []

for cc1 in ccc:
    album_url = \
        album_album_url[0]+cc1['spotify_id']+album_album_url[1]
    print(album_url)
    res = backendFunc.requestUrl(album_url, headers, 'json')
    err_res_list.append(res)
err_res_list
# Out:
# https://api.spotify.com/v1/artists/31W5EY0aAly4Qieq6OFu6I/albums?include_groups=album&limit=50
# https://api.spotify.com/v1/artists/3GhvpQmv0mmLJpQsi7KNKw?aid=&cid=&ctid=&ep_mid=5894031&ep_rid=200243583&mid=&offer=Check+%27Em+Out+Button&play=true&redirect=%2Fprograms%2Fkids-and-family-collection%2Fworkouts&utm_medium=open&utm_source=open.spotify.com/albums?include_groups=album&limit=50
# https://api.spotify.com/v1/artists/4Q5sPmM8j4SpMqL4UA1DtS/albums?include_groups=album&limit=50
# https://api.spotify.com/v1/artists/0JhOScUXAJlH5OZzZd6GNF/albums?include_groups=album&limit=50
# https://api.spotify.com/v1/artists/7uIbLdzzSEqnX0Pkrb56cR/albums?include_groups=album&limit=50
# [{'href': 'https://api.spotify.com/v1/artists/31W5EY0aAly4Qieq6OFu6I/albums?include_groups=album&offset=0&limit=50',
#   'items': [{'album_group': 'album',
#     'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/31W5EY0aAly4Qieq6OFu6I'},
# ...

# %%
# 處理 err 0  boogie
err_res_list[0]
# Out:
# {'href': 'https://api.spotify.com/v1/artists/31W5EY0aAly4Qieq6OFu6I/albums?include_groups=album&offset=0&limit=50',
#  'items': [{'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/31W5EY0aAly4Qieq6OFu6I'},
#      'href': 'https://api.spotify.com/v1/artists/31W5EY0aAly4Qieq6OFu6I',
#      'id': '31W5EY0aAly4Qieq6OFu6I',
#      'name': 'A Boogie Wit da Hoodie',
#      'type': 'artist',
#      'uri': 'spotify:artist:31W5EY0aAly4Qieq6OFu6I'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
# ...

# %%
# 有兩筆，刪除一筆 -->mongo刪除
xxx = newrapID.collection.find({
        "spotify_id":'31W5EY0aAly4Qieq6OFu6I'
    })
for xx in xxx:
    print(xx)
# Out:
# {'_id': ObjectId('6618d91d1c4723b68ac22cf7'), 'artist_ID_url': 'https://open.spotify.com/artist/31W5EY0aAly4Qieq6OFu6I', 'playlist_ID_url': 'https://open.spotify.com/artist/5usbqiU7sjvszjWecANDL6', 'name': 'Boogie', 'spotify_id': '31W5EY0aAly4Qieq6OFu6I', 'followers': 8064287, 'popularity': 80, 'genres': ['melodic rap', 'rap', 'trap'], 'total_albums': 10, 'albums': [{'album_name': 'Me vs. Myself', 'total_tracks_num': 23, 'album_id': '2vM2H6lyPfitmNZlc1Vrxv', 'release_date': '2022-12-12', 'total_artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/31W5EY0aAly4Qieq6OFu6I'}, 'href': 'https://api.spotify.com/v1/artists/31W5EY0aAly4Qieq6OFu6I', 'id': '31W5EY0aAly4Qieq6OFu6I', 'name': 'A Boogie Wit da Hoodie', 'type': 'artist', 'uri': 'spotify:artist:31W5EY0aAly4Qieq6OFu6I'}], 'album_type': 'album', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273bb2f4e170bd0e685d84b9ad7', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616
# ...

# %%
# 尋找collection裡沒有albums 這個field的doc
ccc = newrapID.collection.aggregate([{
        "$match": {
            "albums": { "$exists": False }
        }
    }])
for cc1 in ccc:
    print(cc1['name'])
# Out:
# Cordaro Stewart
# Lil’ Flip
# Torch (German)
# Yo-Yo

# %%
# Cordaro Stewart
#album_url = album_album_url[0]+"3GhvpQmv0mmLJpQsi7KNKw"+album_album_url[1]
album_url = album_album_url[0]+"1HGpqo5iYcvKVv82IUHA9s"+album_album_url[1]
print(album_url)
res = backendFunc.requestUrl(album_url, headers, 'json')

res
# Out:
# https://api.spotify.com/v1/artists/1HGpqo5iYcvKVv82IUHA9s/albums?include_groups=album&limit=50
# {'href': 'https://api.spotify.com/v1/artists/1HGpqo5iYcvKVv82IUHA9s/albums?include_groups=album&offset=0&limit=50',
#  'items': [],
#  'limit': 50,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 0}

# %%
# lil flip
# Cordaro Stewart
album_url = album_album_url[0]+"4Q5sPmM8j4SpMqL4UA1DtS"+album_album_url[1]
print(album_url)
res = backendFunc.requestUrl(album_url, headers, 'json')

res
# Out:
# https://api.spotify.com/v1/artists/4Q5sPmM8j4SpMqL4UA1DtS/albums?include_groups=album&limit=50
# {'href': 'https://api.spotify.com/v1/artists/4Q5sPmM8j4SpMqL4UA1DtS/albums?include_groups=album&offset=0&limit=50',
#  'items': [{'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Q5sPmM8j4SpMqL4UA1DtS'},
#      'href': 'https://api.spotify.com/v1/artists/4Q5sPmM8j4SpMqL4UA1DtS',
#      'id': '4Q5sPmM8j4SpMqL4UA1DtS',
#      'name': "Lil' Flip",
#      'type': 'artist',
#      'uri': 'spotify:artist:4Q5sPmM8j4SpMqL4UA1DtS'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2zaB41HXDxNghkA6X0fgXT'},
#      'href': 'https://api.spotify.com/v1/artists/2zaB41HXDxNghkA6X0fgXT',
#      'id': '2zaB41HXDxNghkA6X0fgXT',
#      'name': 'Rizzoo Rizzoo',
#      'type': 'artist',
#      'uri': 'spotify:artist:2zaB41HXDxNghkA6X0fgXT'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
# ...

# %%
res['next']
# Out:
# 'https://api.spotify.com/v1/artists/4Q5sPmM8j4SpMqL4UA1DtS/albums?include_groups=album&offset=50&limit=50'

# %%
doc = newrapID.collection.find({'name':'Lil’ Flip'})
for d in doc:
    print(d)
# lil flip 兩筆重複資料，刪除一筆
# Out:
# {'_id': ObjectId('6618d9ae1c4723b68ac22f7b'), 'artist_ID_url': 'https://open.spotify.com/artist/4Q5sPmM8j4SpMqL4UA1DtS', 'playlist_ID_url': 'https://open.spotify.com/artist/0CMPwVj5NbqZJZjBmKJ1PF', 'name': 'Lil’ Flip', 'spotify_id': '4Q5sPmM8j4SpMqL4UA1DtS', 'followers': 576558, 'popularity': 54, 'genres': ['crunk', 'dirty south rap'], 'total_albums': 73, 'albums': [{'album_name': 'The Leprechauns', 'total_tracks_num': 9, 'album_id': '56Zv8KoZswwbgW9lQ036yM', 'release_date': '2024-03-17', 'total_artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Q5sPmM8j4SpMqL4UA1DtS'}, 'href': 'https://api.spotify.com/v1/artists/4Q5sPmM8j4SpMqL4UA1DtS', 'id': '4Q5sPmM8j4SpMqL4UA1DtS', 'name': "Lil' Flip", 'type': 'artist', 'uri': 'spotify:artist:4Q5sPmM8j4SpMqL4UA1DtS'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/2zaB41HXDxNghkA6X0fgXT'}, 'href': 'https://api.spotify.com/v1/artists/2zaB41HXDxNghkA6X0fgXT', 'id': '2zaB41HXDxNghkA6X0fgXT', 'name': 'Rizzoo Ri
# ...

# %%
doc = newrapID.collection.find({'name':'Torch (German)'})
for d in doc:
    print(d)
# Yo-Yo 同樣有兩筆，刪除一筆 
# 兩筆重複資料，刪除一筆
# Out:
# {'_id': ObjectId('6618da191c4723b68ac2317a'), 'artist_ID_url': 'https://open.spotify.com/artist/0JhOScUXAJlH5OZzZd6GNF', 'playlist_ID_url': 'https://open.spotify.com/track/6x6aVS1bloX4aNjqjh12iB', 'name': 'Torch (German)', 'spotify_id': '0JhOScUXAJlH5OZzZd6GNF', 'followers': 4232, 'popularity': 17, 'genres': [], 'total_albums': 6, 'albums': [{'album_name': "Where I'm Coming From", 'total_tracks_num': 18, 'album_id': '6CqxrahE2Zr9spiIpyXmsD', 'release_date': '2023-03-08', 'total_artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0JhOScUXAJlH5OZzZd6GNF'}, 'href': 'https://api.spotify.com/v1/artists/0JhOScUXAJlH5OZzZd6GNF', 'id': '0JhOScUXAJlH5OZzZd6GNF', 'name': 'Torch', 'type': 'artist', 'uri': 'spotify:artist:0JhOScUXAJlH5OZzZd6GNF'}], 'album_type': 'album', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b2730ab0fd79007443082b198408', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e020ab0fd79007443082b198408'
# ...

# %% [markdown]
# ### single

# %%
aaaa = newrapID.collection.find({'name':'Madlib'})
for aaa in aaaa:
    print(aaa['spotify_id'])
# Out:
# 5LhTec3c7dcqBvpLRWbMcf

# %%
single_url=  album_single_url[0]+'5LhTec3c7dcqBvpLRWbMcf'+album_single_url[1]

res1 = backendFunc.requestUrl(single_url, headers, 'json')
print(res1)
# Out:
# {'href': 'https://api.spotify.com/v1/artists/5LhTec3c7dcqBvpLRWbMcf/albums?include_groups=single&offset=0&limit=50', 'items': [{'album_group': 'single', 'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0lEssBAxQl2In4RpaB1C2Y'}, 'href': 'https://api.spotify.com/v1/artists/0lEssBAxQl2In4RpaB1C2Y', 'id': '0lEssBAxQl2In4RpaB1C2Y', 'name': 'Talib Kweli', 'type': 'artist', 'uri': 'spotify:artist:0lEssBAxQl2In4RpaB1C2Y'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/5LhTec3c7dcqBvpLRWbMcf'}, 'href': 'https://api.spotify.com/v1/artists/5LhTec3c7dcqBvpLRWbMcf', 'id': '5LhTec3c7dcqBvpLRWbMcf', 'name': 'Madlib', 'type': 'artist', 'uri': 'spotify:artist:5LhTec3c7dcqBvpLRWbMcf'}], 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO
# ...

# %%
res1
# Out:
# {'href': 'https://api.spotify.com/v1/artists/5LhTec3c7dcqBvpLRWbMcf/albums?include_groups=single&offset=0&limit=50',
#  'items': [{'album_group': 'single',
#    'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0lEssBAxQl2In4RpaB1C2Y'},
#      'href': 'https://api.spotify.com/v1/artists/0lEssBAxQl2In4RpaB1C2Y',
#      'id': '0lEssBAxQl2In4RpaB1C2Y',
#      'name': 'Talib Kweli',
#      'type': 'artist',
#      'uri': 'spotify:artist:0lEssBAxQl2In4RpaB1C2Y'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5LhTec3c7dcqBvpLRWbMcf'},
#      'href': 'https://api.spotify.com/v1/artists/5LhTec3c7dcqBvpLRWbMcf',
#      'id': '5LhTec3c7dcqBvpLRWbMcf',
#      'name': 'Madlib',
#      'type': 'artist',
#      'uri': 'spotify:artist:5LhTec3c7dcqBvpLRWbMcf'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
# ...

# %%
for i in range(len(res1['items'])):
    print(res1['items'][i]['name'])
# Out:
# CARNIVAL PACK (feat. Rich The Kid, Playboi Carti)
# CARNIVAL - HOOLIGANS VERSION
# CARNIVAL (feat. Rich The Kid, Playboi Carti)
# CARNIVAL (INSTRUMENTAL)
# TALKING
# VULTURES PACK
# VULTURES
# VULTURES
# Where They At
# Stand United
# Hot Shit (feat. Ye & Lil Durk)
# Hot Shit (feat. Ye & Lil Durk) [Instrumental]
# Eazy
# True Love
# City of Gods
# Hurricane
# Life Of The Party
# Wash Us In The Blood
# I Love It
# XTCY
# Lift Yourself
# Ye vs. the People (starring TI as the People)
# All Day
# FourFiveSeconds
# Only One
# New God Flow
# Mercy
# Cold
# Runaway (Explicit Version)
# Christmas In Harlem
# Paranoid
# Stronger
# Good Life
# Touch The Sky
# Diamonds from Sierra Leone Remix ft Jay.z
# Heard 'Em Say
# Selfish
# All Falls Down
# Through The Wire

# %%
res1['items'][0]
# Out:
# {'album_group': 'single',
#  'album_type': 'single',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4xPQFgDA5M2xa0ZGo5iIsv'},
#    'href': 'https://api.spotify.com/v1/artists/4xPQFgDA5M2xa0ZGo5iIsv',
#    'id': '4xPQFgDA5M2xa0ZGo5iIsv',
#    'name': '¥$',
#    'type': 'artist',
#    'uri': 'spotify:artist:4xPQFgDA5M2xa0ZGo5iIsv'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#    'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#    'id': '5K4W6rqBFWDnAN6FQUkS6x',
#    'name': 'Kanye West',
#    'type': 'artist',
#    'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/7c0XG5cIJTrrAgEC3ULPiq'},
#    'href': 'https://api.spotify.com/v1/artists/7c0XG5cIJTrrAgEC3ULPiq',
#    'id': '7c0XG5cIJTrrAgEC3ULPiq',
#    'name': 'Ty Dolla $ign',
#    'type': 'artist',
#    'uri': 'spotify:artist:7c0XG5cIJTrrAgEC3ULPiq'}],
# ...

# %%
""" 
single response 回傳的
{'album_group': 'single',
 'album_type': 'single',
 'artists': [],
 'available_markets': ['AR','JO'],
 'external_urls': {'spotify': 'https://open.spotify.com/album/7pX434FLw0bG1BPKVAyRfk'},
 'href': 'https://api.spotify.com/v1/albums/7pX434FLw0bG1BPKVAyRfk',
 'id': '7pX434FLw0bG1BPKVAyRfk',
 'images': [],
 'name': 'CARNIVAL PACK (feat. Rich The Kid, Playboi Carti)',
 'release_date': '2024-02-08',
 'release_date_precision': 'day',
 'total_tracks': 5,
 'type': 'album',
 'uri': 'spotify:album:7pX434FLw0bG1BPKVAyRfk'} """

# 新增 total_singles / singles 外層
# 新增在 singles中-->
# single_name
# total_tracks
# single_id
# release_date
# total_artists
# album_type
# images

# %%
# 確定有href 來更新 增加 doc的 singles欄位
def add_single_from_response(old_dict, response):
    new_dict = old_dict.copy()

    if 'singles' not in new_dict.keys():
        new_dict['total_singles'] = response['total']
        new_dict['singles'] = []
    
    for i in range(len(response['items'])): # for each album in item
        one_single = response['items'][i]
        temp_dict = {}
        temp_dict['single_name'] = one_single['name']
        temp_dict['total_singles_num'] = one_single['total_tracks']
        temp_dict['single_id'] = one_single['id']
        temp_dict['release_date'] = one_single['release_date']
        temp_dict['total_artists'] = one_single['artists']
        temp_dict['album_type'] = one_single['album_type']
        temp_dict['images'] = one_single['images']

        new_dict['singles'].append(temp_dict)     

    return new_dict

# %%
aaaa

# %%
aaa = newrapID.collection.find_one({'name': 'Madlib'})
print(aaa)
# Out:
# {'_id': ObjectId('6618d9be1c4723b68ac22fc5'), 'artist_ID_url': 'https://open.spotify.com/artist/5LhTec3c7dcqBvpLRWbMcf', 'playlist_ID_url': 'https://open.spotify.com/playlist/37i9dQZF1DZ06evO3ovxb6', 'name': 'Madlib', 'spotify_id': '5LhTec3c7dcqBvpLRWbMcf', 'followers': 473725, 'popularity': 68, 'genres': ['abstract hip hop', 'alternative hip hop', 'hip hop', 'instrumental hip hop', 'psychedelic hip hop'], 'total_albums': 54, 'albums': [{'album_name': 'Liberation 2', 'total_tracks_num': 15, 'album_id': '0zsoWKnMDhi7TgMMST7sYn', 'release_date': '2024-04-12', 'total_artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0lEssBAxQl2In4RpaB1C2Y'}, 'href': 'https://api.spotify.com/v1/artists/0lEssBAxQl2In4RpaB1C2Y', 'id': '0lEssBAxQl2In4RpaB1C2Y', 'name': 'Talib Kweli', 'type': 'artist', 'uri': 'spotify:artist:0lEssBAxQl2In4RpaB1C2Y'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/5LhTec3c7dcqBvpLRWbMcf'}, 'href': 'https://api.spotify.com/v1/artists/5Lh
# ...

# %%
single_url=  album_single_url[0]+'5LhTec3c7dcqBvpLRWbMcf'+album_single_url[1]

res1 = backendFunc.requestUrl(single_url, headers, 'json')
res1
# Out:
# {'href': 'https://api.spotify.com/v1/artists/5LhTec3c7dcqBvpLRWbMcf/albums?include_groups=single&offset=0&limit=50',
#  'items': [{'album_group': 'single',
#    'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0lEssBAxQl2In4RpaB1C2Y'},
#      'href': 'https://api.spotify.com/v1/artists/0lEssBAxQl2In4RpaB1C2Y',
#      'id': '0lEssBAxQl2In4RpaB1C2Y',
#      'name': 'Talib Kweli',
#      'type': 'artist',
#      'uri': 'spotify:artist:0lEssBAxQl2In4RpaB1C2Y'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5LhTec3c7dcqBvpLRWbMcf'},
#      'href': 'https://api.spotify.com/v1/artists/5LhTec3c7dcqBvpLRWbMcf',
#      'id': '5LhTec3c7dcqBvpLRWbMcf',
#      'name': 'Madlib',
#      'type': 'artist',
#      'uri': 'spotify:artist:5LhTec3c7dcqBvpLRWbMcf'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
# ...

# %%
try_ = add_single_from_response(aaa, res1)
try_
# Out:
# {'_id': ObjectId('6618d9be1c4723b68ac22fc5'),
#  'artist_ID_url': 'https://open.spotify.com/artist/5LhTec3c7dcqBvpLRWbMcf',
#  'playlist_ID_url': 'https://open.spotify.com/playlist/37i9dQZF1DZ06evO3ovxb6',
#  'name': 'Madlib',
#  'spotify_id': '5LhTec3c7dcqBvpLRWbMcf',
#  'followers': 473725,
#  'popularity': 68,
#  'genres': ['abstract hip hop',
#   'alternative hip hop',
#   'hip hop',
#   'instrumental hip hop',
#   'psychedelic hip hop'],
#  'total_albums': 54,
#  'albums': [{'album_name': 'Liberation 2',
#    'total_tracks_num': 15,
#    'album_id': '0zsoWKnMDhi7TgMMST7sYn',
#    'release_date': '2024-04-12',
#    'total_artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0lEssBAxQl2In4RpaB1C2Y'},
#      'href': 'https://api.spotify.com/v1/artists/0lEssBAxQl2In4RpaB1C2Y',
#      'id': '0lEssBAxQl2In4RpaB1C2Y',
#      'name': 'Talib Kweli',
#      'type': 'artist',
#      'uri': 'spotify:artist:0lEssBAxQl2In4RpaB1C2Y'},
# ...

# %%
album_single_url = [f'https://api.spotify.com/v1/artists/', 
                    f'/albums?include_groups=single&limit=50']

# %%
# update singles
# 更新 new_rap_ID
newrapID = Spotify('new_rap_ID')
type, token = backendFunc.checkToken('spotify_token', search_ID)
headers = {'Authorization': f"{type} {token}"}
docs = newrapID.collection.find({})

error_doc_list = []
for index,doc in enumerate(docs):
    if '_id' in doc.keys():
        del doc['_id']
    # each doc get artist_album_url
    artist_single_url=  album_single_url[0]+doc['spotify_id']+album_single_url[1]
    
    try:
        # 抓資料
        try:
            init_response = backendFunc.requestUrl(artist_single_url, headers, 'json')
        except:
            print('soptify api error and update headers')
            # update headers
            type, token = backendFunc.checkToken('spotify_token', search_ID)
            headers = {'Authorization': f"{type} {token}"}
            init_response = backendFunc.requestUrl(artist_single_url, headers, 'json')


        response  = init_response
        artist_new_dict = add_single_from_response(doc, response)
        while response['next'] is not None:
            # 抓資料
            try:
                after_response = backendFunc.requestUrl(response['next'], headers, 'json')
            except:
                print('soptify api error')
                # update headers
                type, token = backendFunc.checkToken('spotify_token', search_ID)
                headers = {'Authorization': f"{type} {token}"}
                after_response = backendFunc.requestUrl(response['next'], headers, 'json')
            
            artist_new_dict = add_single_from_response(artist_new_dict, after_response)
            response = after_response
        # 更新資料
        # 使用 replace_one() 方法替换匹配条件的第一个文档
        query = {'spotify_id': doc['spotify_id']}
        newrapID.collection.replace_one(query, artist_new_dict)
        #print("update index ", index, 'done')

    except:
        temp_err_dict = {}
        temp_err_dict['index'] = index
        temp_err_dict['artist_name'] = doc['name']
        temp_err_dict['spotify_id'] = doc['spotify_id']

        print("index ", index, ' error')
        print("append index and artist name")
        error_doc_list.append(temp_err_dict)

# %%
len(error_doc_list)
# Out:
# 0

# %%
# check
bbbb = newrapID.collection.aggregate([{
    "$match":{
        "singles":
        {"$exists":False}
    }
}])

for bbb in bbbb:
    print(bbb)

# %%
n  = newrapID.collection.find_one({'name':"Cordaro Stewart"})
n
# Out:
# {'_id': ObjectId('6618d9551c4723b68ac22de2'),
#  'artist_ID_url': 'https://open.spotify.com/artist/3GhvpQmv0mmLJpQsi7KNKw',
#  'playlist_ID_url': 'https://open.spotify.com/artist/1HGpqo5iYcvKVv82IUHA9s',
#  'name': 'Cordaro Stewart',
#  'spotify_id': '3GhvpQmv0mmLJpQsi7KNKw',
#  'followers': 1,
#  'popularity': 0,
#  'genres': [],
#  'total_singles': 0,
#  'singles': []}

# %%
nnn = newrapID.collection.find({'spotify_id':"3GhvpQmv0mmLJpQsi7KNKw"})
for m in nnn:
    print(m)
# Out:
# {'_id': ObjectId('6618d9551c4723b68ac22de2'), 'artist_ID_url': 'https://open.spotify.com/artist/3GhvpQmv0mmLJpQsi7KNKw', 'playlist_ID_url': 'https://open.spotify.com/artist/1HGpqo5iYcvKVv82IUHA9s', 'name': 'Cordaro Stewart', 'spotify_id': '3GhvpQmv0mmLJpQsi7KNKw', 'followers': 1, 'popularity': 0, 'genres': [], 'total_singles': 0, 'singles': []}

# %%
# C. stewart
nnn = newrapID.collection.find({'spotify_id':"1HGpqo5iYcvKVv82IUHA9s"})
for m in nnn:
    print(m)

# %%
# C. stewart
nnn = newrapID.collection.find_one({'spotify_id':"1HGpqo5iYcvKVv82IUHA9s"})
print(nnn)
# Out:
# {'_id': ObjectId('6618d9551c4723b68ac22de2'), 'artist_ID_url': 'https://open.spotify.com/artist/3GhvpQmv0mmLJpQsi7KNKw', 'playlist_ID_url': 'https://open.spotify.com/artist/1HGpqo5iYcvKVv82IUHA9s', 'name': 'Cordaro Stewart', 'spotify_id': '1HGpqo5iYcvKVv82IUHA9s', 'followers': 1, 'popularity': 0, 'genres': [], 'total_singles': 0, 'singles': []}

# %%
cstw_url = '1HGpqo5iYcvKVv82IUHA9s'
cstw_album_url = album_album_url[0]+cstw_url+album_album_url[1]
cstw_single_url = album_single_url[0]+cstw_url+album_single_url[1]

# %%
res11 = backendFunc.requestUrl(cstw_album_url, headers, 'json')
res11
# Out:
# {'href': 'https://api.spotify.com/v1/artists/1HGpqo5iYcvKVv82IUHA9s/albums?include_groups=album&offset=0&limit=50',
#  'items': [],
#  'limit': 50,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 0}

# %%
res22 = backendFunc.requestUrl(cstw_single_url, headers, 'json')
res22
# Out:
# {'href': 'https://api.spotify.com/v1/artists/1HGpqo5iYcvKVv82IUHA9s/albums?include_groups=single&offset=0&limit=50',
#  'items': [{'album_group': 'single',
#    'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HGpqo5iYcvKVv82IUHA9s'},
#      'href': 'https://api.spotify.com/v1/artists/1HGpqo5iYcvKVv82IUHA9s',
#      'id': '1HGpqo5iYcvKVv82IUHA9s',
#      'name': 'C. Stewart',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HGpqo5iYcvKVv82IUHA9s'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
# ...

# %%
cstw_artist_url = artist_endpoint+ cstw_url
res33 = backendFunc.requestUrl(cstw_artist_url, headers, 'json')
res33
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/1HGpqo5iYcvKVv82IUHA9s'},
#  'followers': {'href': None, 'total': 372},
#  'genres': [],
#  'href': 'https://api.spotify.com/v1/artists/1HGpqo5iYcvKVv82IUHA9s',
#  'id': '1HGpqo5iYcvKVv82IUHA9s',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab6761610000e5eb59b47d7d609071d6a1d66a94',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/ab6761610000517459b47d7d609071d6a1d66a94',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/ab6761610000f17859b47d7d609071d6a1d66a94',
#    'width': 160}],
#  'name': 'C. Stewart',
#  'popularity': 0,
#  'type': 'artist',
#  'uri': 'spotify:artist:1HGpqo5iYcvKVv82IUHA9s'}

# %%
newrapID = Spotify('new_rap_ID')
hhhhh = newrapID.collection.find_one({'name':'C. Stewart'})
print(hhhhh)
# Out:
# {'_id': ObjectId('6618da3e1c4723b68ac2322b'), 'artist_ID_url': 'https://open.spotify.com/artist/1HGpqo5iYcvKVv82IUHA9s', 'playlist_ID_url': 'https://open.spotify.com/playlist/37i9dQZF1E4vgW0cbrc6EI', 'name': 'C. Stewart', 'spotify_id': '1HGpqo5iYcvKVv82IUHA9s', 'followers': 372, 'popularity': 0, 'genres': []}

# %%
# Out:
# {'_id': ObjectId('6618d9551c4723b68ac22de2'),
#  'artist_ID_url': 'https://open.spotify.com/artist/3GhvpQmv0mmLJpQsi7KNKw',
#  'playlist_ID_url': 'https://open.spotify.com/artist/1HGpqo5iYcvKVv82IUHA9s',
#  'name': 'Cordaro Stewart',
#  'spotify_id': '1HGpqo5iYcvKVv82IUHA9s',
#  'followers': 1,
#  'popularity': 0,
#  'genres': [],
#  'total_singles': 0,
#  'singles': []}

# %%
h33 = add_single_from_response(hhhhh, res22)
h33 = add_album_from_response(h33, res11)


query = {'spotify_id': '1HGpqo5iYcvKVv82IUHA9s'}
newrapID.collection.replace_one(query, h33)
#print("update index ", index, 'done')
# Out:
# UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
kkl = newrapID.collection.find_one({'name':'C. Stewart'})
print(kkl)
# Out:
# None

# %%
# nasty c 有兩筆重複的 變回 c.stewart
#c. stewart query = {'spotify_id': '1HGpqo5iYcvKVv82IUHA9s'}
# fixed

# %%
wb_doc = {}
wb_doc['name'] = 'WESTSIDE BOOGIE'
wb_doc['artist_ID_url'] = 'https://open.spotify.com/artist/5usbqiU7sjvszjWecANDL6'
wb_doc['playlist_ID_url'] = 'https://open.spotify.com/artist/1udteKroyLdiMRdwYmz6LF'
wb_doc['spotify_id'] = '5usbqiU7sjvszjWecANDL6'
wb_doc['followers'] = 316163
wb_doc['popularity'] = 55
wb_doc['genres'] = ['canadian hip hop', 'indie hip hop', 'underground hip hop']
wb_doc
# Out:
# {'name': 'WESTSIDE BOOGIE',
#  'artist_ID_url': 'https://open.spotify.com/artist/5usbqiU7sjvszjWecANDL6',
#  'playlist_ID_url': 'https://open.spotify.com/artist/1udteKroyLdiMRdwYmz6LF',
#  'spotify_id': '5usbqiU7sjvszjWecANDL6',
#  'followers': 316163,
#  'popularity': 55,
#  'genres': ['canadian hip hop', 'indie hip hop', 'underground hip hop']}

# %%
type, token = backendFunc.checkToken('spotify_token', search_ID)
headers = {'Authorization': f"{type} {token}"}

wb_url = '5usbqiU7sjvszjWecANDL6'
wb_album_url = album_album_url[0]+wb_url+album_album_url[1]
wb_single_url = album_single_url[0]+ wb_url+album_single_url[1]
wb_artist_url = artist_endpoint+wb_url

wb11 = backendFunc.requestUrl(wb_album_url, headers, 'json')
wb22 = backendFunc.requestUrl(wb_single_url, headers, 'json')
wb33 = backendFunc.requestUrl(wb_artist_url, headers, 'json')

# %%
# 要手動寫入 westside boogie的資料
wb33 = add_single_from_response(wb_doc, wb22)
wb33 = add_album_from_response(wb33, wb11)

newrapID.insert_one(wb33)
# Out:
# InsertOneResult(ObjectId('661d1b8093f528b2be122e56'), acknowledged=True)

# %%
# done

# %% [markdown]
# ######### 2. add rapper images

# %%
# add images
# get spotify_ids
newrapID = Spotify('new_rap_ID')
spotify_ids = [doc["spotify_id"] for doc in newrapID.collection.find()]
spotify_ids.sort()
print(spotify_ids)
# Out:
# ['00G1NTDAoU7rBpjG4KoYAM', '00fUxTsDQ3TMlro9Abk6bG', '01DTVE3KmoPogPZaOvMqO8', '01QTIT5P1pFP3QnnFSdsJf', '01nVIuD8YZsnFH6x6Cc9rX', '02WFRlMwbZO6QfBJgZRNFa', '02kJSzxNuaWGqwubyUba0Z', '03WVr99PSOANMZlM50L6u5', '03nubJOsC1lpypeBSKaRL2', '03ojdQidPtScdEq8KU2V9K', '03pn54eB540z8IuK6LYXH9', '04GaFBkrXgbjuLYvlHP3FW', '04HECiWVE4ogBNdOvJuyps', '04hnAYmbQTSSJ91sqaI4EW', '05cqfWVtssCo3KVcqEAYG3', '06OvAoYzrmpboMcCCKlFlz', '06igEJihmryrn6c90emRzu', '07EcmJpfAday8xGkslfanE', '07VmOvmuBp9G0gb8BTrpn0', '07W0YfsvHM7Mw7Bq48Mb0A', '07YZf4WDAMNwqr4jfgOZ8y', '07d5etnpjriczFBB8pxmRe', '085pc2PYOi8bGKj0PNjekA', '08892NttEPASDR63eM1joO', '08HRN7hYxMxJ4BOMP0TJK6', '08Ld63UgKrJ0nZnCkzHtzc', '08RVkVEdLLoTgd5YbXHOIC', '099tLNCZZvtjC7myKD0mFp', '09ci97mGlIVzXxSRGEKPxl', '0A0FS04o6zMoto8OKPsDwY', '0A8IvMuH8NLgUGd9eKqGxA', '0AAfOtcrctNWvDpe2AKB1M', '0ABk515kENDyATUdpCKVfW', '0AUiVacFmIUoovbW24SyWN', '0AWhixY9hX7LEPyPMjh4O0', '0AoX5cRnGojriIX6lxmP0D', '0AqfGv5Nifg1klh0iH4Nqs', '0Bi7gsMOc5xrBd3gSfGsFZ', '0BrPKSAe
# ...

# %%
len(spotify_ids)
# Out:
# 1357

# %%
artist_endpoint
# Out:
# 'https://api.spotify.com/v1/artists/'

# %%
test = newrapID.collection.find_one({'name':"WESTSIDE BOOGIE"})
wb_artist_url = artist_endpoint+ test['spotify_id']

res = backendFunc.requestUrl(wb_artist_url, headers, 'json')
res
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/5usbqiU7sjvszjWecANDL6'},
#  'followers': {'href': None, 'total': 316163},
#  'genres': ['canadian hip hop', 'indie hip hop', 'underground hip hop'],
#  'href': 'https://api.spotify.com/v1/artists/5usbqiU7sjvszjWecANDL6',
#  'id': '5usbqiU7sjvszjWecANDL6',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab6761610000e5eb91ddb9259985ccc7361452e4',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/ab6761610000517491ddb9259985ccc7361452e4',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/ab6761610000f17891ddb9259985ccc7361452e4',
#    'width': 160}],
#  'name': 'WESTSIDE BOOGIE',
#  'popularity': 55,
#  'type': 'artist',
#  'uri': 'spotify:artist:5usbqiU7sjvszjWecANDL6'}

# %%
if "images" in res.keys():
    print(True)
# Out:
# True

# %%
# for each doc by spotify id
type, token = backendFunc.checkToken('spotify_token', search_ID)
headers = {'Authorization': f"{type} {token}"}

error_doc_list = []
for i, v in enumerate(spotify_ids):
    temp_doc = newrapID.collection.find_one({'spotify_id':v})
    artist_url = artist_endpoint+v
    try:
        # 抓資料
        try:
            response = backendFunc.requestUrl(artist_url, headers, 'json')
        except:
            print('soptify api error and update headers')
            # update headers
            type, token = backendFunc.checkToken('spotify_token', search_ID)
            headers = {'Authorization': f"{type} {token}"}
            response = backendFunc.requestUrl(artist_url, headers, 'json')

        # spotify api have rapper image
        if 'images' in response.keys():
            # 定義要更新的 document
            filter = {"spotify_id": v}
            # 定義要增加的 field
            new_field = {"images": response['images']}
            # 使用 update_one() 方法增加 field
            newrapID.collection.update_one(filter, {"$set": new_field})
        else:
            temp_err_dict = {}
            temp_err_dict['index'] = i
            temp_err_dict['artist_name'] = temp_doc['name']
            temp_err_dict['spotify_id'] = v

            print("index ", index, ' error')
            print("append error index and artist name")
            error_doc_list.append(temp_err_dict)

    except:
        temp_err_dict = {}
        temp_err_dict['index'] = i
        temp_err_dict['artist_name'] = temp_doc['name']
        temp_err_dict['spotify_id'] = v

        print("index ", index, ' error')
        print("append index and artist name")
        error_doc_list.append(temp_err_dict)

# %%
error_doc_list
# Out:
# []

# %%
# done

# %% [markdown]
# ################ 3. make tracks db

# %%
# transform one data
newrapID = Spotify('new_rap_ID')
ye_doc = newrapID.collection.find_one({'name':'Kanye West'})
ye_doc
# Out:
# {'_id': ObjectId('6618d99c1c4723b68ac22f24'),
#  'artist_ID_url': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x',
#  'playlist_ID_url': 'https://open.spotify.com/album/2Ek1q2haOnxVqhvVKqMvJe',
#  'name': 'Kanye West',
#  'spotify_id': '5K4W6rqBFWDnAN6FQUkS6x',
#  'followers': 24777743,
#  'popularity': 94,
#  'genres': ['chicago rap', 'hip hop', 'rap'],
#  'total_albums': 16,
#  'albums': [{'album_name': 'VULTURES 1',
#    'total_tracks_num': 16,
#    'album_id': '30zwjSQEodaUXCn11nmiVF',
#    'release_date': '2024-02-09',
#    'total_artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4xPQFgDA5M2xa0ZGo5iIsv'},
#      'href': 'https://api.spotify.com/v1/artists/4xPQFgDA5M2xa0ZGo5iIsv',
#      'id': '4xPQFgDA5M2xa0ZGo5iIsv',
#      'name': '¥$',
#      'type': 'artist',
#      'uri': 'spotify:artist:4xPQFgDA5M2xa0ZGo5iIsv'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
# ...

# %%
album_id = ye_doc['albums'][6]['album_id']
single_id = ye_doc['singles'][6]['single_id']
print(ye_doc['albums'][6]['album_name'])
print(album_id) 
print(ye_doc['singles'][5]['single_name'])
print(single_id)
# Out:
# The Life Of Pablo
# 7gsWAHLeT0w7es6FofOXk1
# VULTURES PACK
# 4BdfszFenZ1eMrISGvourZ

# %%
# get spotify api
id = album_id
album_endpoint=f'https://api.spotify.com/v1/albums/{id}/tracks?limit=50'
album_endpoint
# Out:
# 'https://api.spotify.com/v1/albums/7gsWAHLeT0w7es6FofOXk1/tracks?limit=50'

# %%
type, token = backendFunc.checkToken('spotify_token', search_ID)
headers = {'Authorization': f"{type} {token}"}
res1 = backendFunc.requestUrl(album_endpoint, headers, 'json')
res1
# Out:
# {'href': 'https://api.spotify.com/v1/albums/7gsWAHLeT0w7es6FofOXk1/tracks?offset=0&limit=50',
#  'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#      'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#      'id': '5K4W6rqBFWDnAN6FQUkS6x',
#      'name': 'Kanye West',
#      'type': 'artist',
#      'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
# ...

# %%
""" 
album_track_collection fields for each doc
album_name(one)
album_id(one)
album_image(multi)
album_type(one)
album_href(one)

artist_name(one) under whose album
artist_id(one)

total_tracks(one)
tracks (multi)
    track_name(one)
    track_id(one)
    disc_number(one)
    track_number(one)
    durattion_ms(one)
    track_type(one)
    track_href(one)
    preview_url(one)

"""
res1['items'][3]
# Out:
# {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#    'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#    'id': '5K4W6rqBFWDnAN6FQUkS6x',
#    'name': 'Kanye West',
#    'type': 'artist',
#    'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'}],
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
# ...

# %%
single_id
single_endpoint = f'https://api.spotify.com/v1/albums/{single_id}/tracks?limit=50'
print(id)
single_endpoint
# Out:
# 4BdfszFenZ1eMrISGvourZ
# 'https://api.spotify.com/v1/albums/4BdfszFenZ1eMrISGvourZ/tracks?limit=50'

# %%
type, token = backendFunc.checkToken('spotify_token', search_ID)
headers = {'Authorization': f"{type} {token}"}
res2 = backendFunc.requestUrl(single_endpoint, headers, 'json')
res2
# Out:
# {'href': 'https://api.spotify.com/v1/albums/4BdfszFenZ1eMrISGvourZ/tracks?offset=0&limit=50',
#  'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4xPQFgDA5M2xa0ZGo5iIsv'},
#      'href': 'https://api.spotify.com/v1/artists/4xPQFgDA5M2xa0ZGo5iIsv',
#      'id': '4xPQFgDA5M2xa0ZGo5iIsv',
#      'name': '¥$',
#      'type': 'artist',
#      'uri': 'spotify:artist:4xPQFgDA5M2xa0ZGo5iIsv'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#      'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#      'id': '5K4W6rqBFWDnAN6FQUkS6x',
#      'name': 'Kanye West',
#      'type': 'artist',
#      'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/7c0XG5cIJTrrAgEC3ULPiq'},
#      'href': 'https://api.spotify.com/v1/artists/7c0XG5cIJTrrAgEC3ULPiq',
#      'id': '7c0XG5cIJTrrAgEC3ULPiq',
#      'name': 'Ty Dolla $ign',
# ...

# %%
res2['items'][0].keys()
# Out:
# dict_keys(['artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_urls', 'href', 'id', 'is_local', 'name', 'preview_url', 'track_number', 'type', 'uri'])

# %%
res2['items'][0]
# Out:
# {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4xPQFgDA5M2xa0ZGo5iIsv'},
#    'href': 'https://api.spotify.com/v1/artists/4xPQFgDA5M2xa0ZGo5iIsv',
#    'id': '4xPQFgDA5M2xa0ZGo5iIsv',
#    'name': '¥$',
#    'type': 'artist',
#    'uri': 'spotify:artist:4xPQFgDA5M2xa0ZGo5iIsv'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#    'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#    'id': '5K4W6rqBFWDnAN6FQUkS6x',
#    'name': 'Kanye West',
#    'type': 'artist',
#    'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/7c0XG5cIJTrrAgEC3ULPiq'},
#    'href': 'https://api.spotify.com/v1/artists/7c0XG5cIJTrrAgEC3ULPiq',
#    'id': '7c0XG5cIJTrrAgEC3ULPiq',
#    'name': 'Ty Dolla $ign',
#    'type': 'artist',
#    'uri': 'spotify:artist:7c0XG5cIJTrrAgEC3ULPiq'},
# ...

# %%
# total_singles+ total_albums = 49744 
# total_albums = 13729

# %% [markdown]
# ######### 4. modify flask to new collection
